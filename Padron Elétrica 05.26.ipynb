# %% [markdown]
# <a href="https://colab.research.google.com/github/razcarneiro/Aula-Logica-de-Programacao/blob/main/Padron%20El%C3%A9trica%2005.26.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Criar porjeto eletrico com base em orçamento para clientes diversos.
#Pedir dados dos clientes para coleta de dados e gerir orçamento personalizado.


print("=" * 60)
print("  ⚡  SISTEMA DE ORÇAMENTO - Padron Elétrica ⚡ ")
print("=" * 60)

# Coletando dados do cliente e instalação
print("\n--- DADOS DO CLIENTE ---")
nome_cliente = input("Nome do cliente: ")
tipo_imovel = input("Tipo de imóvel (residencial/comercial/industrial): ").lower()

print("\n---📊 DADOS DA INSTALAÇÃO ---")
metros_quadrados = float(input("Área do imóvel (m²): "))
quantidade_comodos = int(input("Quantidade de cômodos: "))
projeto_eletrico = input("Possui projeto elétrico? (s/n): ").lower()

print("\n--- 📝 NESSECIDADES ESPECÍFICAS  ---")
ar_condicionado = input("Vai instalar ar condicionado? ❄️ (s/n): ").lower()
quantidade_ar = int(input("Quantos aparelhos de ar condicionado? ❄️ ") if ar_condicionado == "s" else "0")
chuveiro_eletrico = input("Vai usar chuveiro elétrico? 🚿 (s/n): ").lower()
chuveiro_eletrico_quantidade = int(input("Quantos chuveiros elétricos? 🚿 ") if chuveiro_eletrico == "s" else "0") # Renamed to avoid confusion with the 's'/'n' variable
automacao = input("Deseja automação residencial? 📲 (s/n): ").lower()

print("\n" + "=" * 60)
print(" 📊[] CALCULANDO ORÇAMENTO E ANÁLISE TÉCNICA...")
print("=" * 60)

# Cálculo do custo base
custo_base = 0

# Custo por tipo de imóvel
if tipo_imovel == "residencial":
    custo_base = metros_quadrados * 75
    print(f"\n✓ Imóvel residencial: R$ {custo_base:.2f} (base)")
elif tipo_imovel == "comercial":
    custo_base = metros_quadrados * 110
    print(f"\n✓ Imóvel comercial: R$ {custo_base:.2f} (base - normas mais rigorosas)")
elif tipo_imovel == "industrial":
    custo_base = metros_quadrados * 180
    print(f"\n✓ Imóvel industrial: R$ {custo_base:.2f} (base - alta complexidade)")
else:
    print(f"\n❌ Tipo de imóvel inválido! Consulte um de nossos consultores.")
    exit()

# Acréscimos baseados nas necessidades
custo_adicional = 0

# Ar condicionado
if ar_condicionado == "s" and quantidade_ar > 0:
    custo_ar = quantidade_ar * 450
    custo_adicional += custo_ar
    print(f"✓ Instalação de {quantidade_ar} ar(es) condicionado(s): + R$ {custo_ar:.2f}")

    # Verificação de capacidade
    if quantidade_ar > quantidade_comodos:
        print(f"  ⚠️ ALERTA: {quantidade_ar} aparelhos para {quantidade_comodos} cômodos. Revisar necessidade!")
    elif quantidade_ar > 3 and tipo_imovel == "residencial":
        print(f"  ℹ️ DICA: Para {quantidade_ar} aparelhos, considere um sistema de ar centralizado")
else:
    print("✗ Sem ar condicionado")

# Chuveiro elétrico
if chuveiro_eletrico == "s" and chuveiro_eletrico_quantidade > 0:
    custo_chuveiro = chuveiro_eletrico_quantidade * 350 # Cost per shower
    custo_adicional += custo_chuveiro
    print(f"✓ Instalação de {chuveiro_eletrico_quantidade} chuveiro(s) elétrico(s): + R$ {custo_chuveiro:.2f}")

    # Verificação para múltiplos chuveiros
    if chuveiro_eletrico_quantidade > 1:
        print(f"  ℹ️ Para imóveis com mais de 1 chuveiro elétrico, considere sistema de Potência.")
else:
    print("✗ Sem chuveiro elétrico")

# Automação residencial
if automacao == "s":
    custo_automacao = metros_quadrados * 35
    custo_adicional += custo_automacao
    print(f"✓ Automação residencial 📲: + R$ {custo_automacao:.2f}")

    if tipo_imovel == "industrial":
        print(f"  🏭 Automação industrial requer engenheiro especializado.")
    elif tipo_imovel == "comercial":
        print(f"  📲 Automação comercial inclui sistema de gerenciamento de energia.")
else:
    print("✗ 📲 Sem automação")

# Projeto elétrico
if projeto_eletrico == "s":
    desconto_projeto = 500
    print(f"✓ Cliente possui projeto elétrico: 🗂️ - R$ {desconto_projeto:.2f} de desconto.")
    custo_adicional -= desconto_projeto
else:
    custo_projeto = 800
    custo_adicional += custo_projeto
    print(f"✗ Sem projeto elétrico: 🗂️ + R$ {custo_projeto:.2f} (necessário elaborar projeto)")

print("\n---  ⛑️ SEGURANÇA ---")
imovel_antigo = input("Imóvel é antigo (mais de 30 anos)? (s/n): ").lower()
fiacao_existente = input("Já possui reforma elétrica com menos de 10 anos? (s/n): ").lower()

# Verificação de segurança
custo_seguranca = 0

if imovel_antigo == "s": # Se a porpiedade é antiga.
    print("\n--- ANÁLISE DE SEGURANÇA PARA IMÓVEL ANTIGO ---")
    if fiacao_existente == "n": # Propiedade antiga, sem reforma recente.
        print("⚠️ ATENÇÃO: Imóvel antigo sem reforma elétrica recente!")
        print("  → Recomendamos substituição completa da fiação")
        custo_seguranca += 1500
        print(f"  → Substituição de fiação: + R$ {custo_seguranca:.2f}")

        if tipo_imovel == "industrial":
            custo_seguranca += 2500
            print(f"  → Adequação às normas industriais: + R$ 2500.00")
    else: # Porpiedade com reforma recente (fiacao_existente == "s")
        print("✓ Imóvel antigo com reforma elétrica recente. Avaliar qualidade da reforma.")
        custo_seguranca += 300 # Custo base para revisão de reforço elétrico estrutural.
        print(f"  → Vistoria técnica e reforços estruturais: + R$ {custo_seguranca:.2f}")

    # Alerta comum para propiedades antigas sem estatus de reformas.
    print("  🔴 ALERTA: Imóveis antigos geralmente têm carga elétrica insuficiente!")
    print("  → Recomendamos upgrade do padrão de entrada para 3 fases + Neutro (Aumento de carga).")
    custo_seguranca += 1300
    print(f"  → Upgrade padrão de entrada: + R$ 1300.00")
else: # If imovel_antigo == "n" (Propiedade não é antiga)
    if fiacao_existente == "n": # Não é antigo e não possui fiação recente (Nova construção sem fiação existente ainda)
        print("✓ Imóvel recente sem fiação existente ou instalação nova.")
    else: # Não é antigo e possui fiação reformada recentemente (fiacao_existente == "s")
        print("✓ Imóvel recente com fiação existente reformada em menos de 10 anos. Instalação padrão.")


# Custo total
custo_total = custo_base + custo_adicional + custo_seguranca

print("\n" + "=" * 60)
print("RESUMO DO ORÇAMENTO")
print("=" * 60)
print(f"Cliente: {nome_cliente}")
print(f"Tipo de imóvel: {tipo_imovel.upper()}")
print(f"Área: {metros_quadrados} m² | Cômodos: {quantidade_comodos}")
print("-" * 60)
print(f"Custo base: R$ {custo_base:.2f}")
print(f"Custos adicionais: R$ {custo_adicional:.2f}")
print(f"Segurança/adequação: R$ {custo_seguranca:.2f}")
print("-" * 60)
print(f"TOTAL DO ORÇAMENTO: R$ {custo_total:.2f}")
print("=" * 60)

# Recomendações finais baseadas em if/else
print("\n--- RECOMENDAÇÕES TÉCNICAS ---")

# Verifica necessidade de  técnico ou engenheiro na obra.
if tipo_imovel == "industrial":
    print("📌 Necessário engenheiro eletricista responsável (CREA).")
elif tipo_imovel == "comercial" and metros_quadrados > 300:
    print("📌 Recomendamos supervisão de um eletro técnico ou engenheiro eletricista da Padron Elétrica na sua obra.")
elif custo_total > 15000:
    print("📌 Projeto de alto valor - contrate um engenheiro da Padron Elétrica para evitar problemas e retrabalho na sua obra.")
else:
    print("📌 Instalação pode ser realizada por equipe técnica qualificada da Padron Elétrica")

# Verifica prazo de execução
if tipo_imovel == "residencial":
    if metros_quadrados < 100:
        prazo = 4
        print(f"📅 Prazo estimado: {prazo} dias úteis (instalação simples)")
    elif metros_quadrados < 250:
        prazo = 7
        print(f"📅 Prazo estimado: {prazo} dias úteis (instalação média)")
    else:
        prazo = 12
        print(f"📅 Prazo estimado: {prazo} dias úteis (instalação baixa complexidade)")
elif tipo_imovel == "comercial":
    prazo = 15
    print(f"📅 Prazo estimado: {prazo} dias úteis (comercial exige mais atenção)")
else:  # industrial
    prazo = 30
    print(f"📅 Prazo estimado: {prazo} dias úteis (industrial - alta complexidade)")

# Verifica necessidade de projeto especial
if automacao == "s" and ar_condicionado == "s":
    print("🤖 RECOMENDAÇÃO ESPECIAL: Sistema integrado de automação + ar condicionado")
    print("   → Isso pode gerar economia de energia de até 30%")

    if tipo_imovel == "comercial": # Removed emoji for consistency
        print("   → Considere sistema de gestão de energia (SGE)")

# Aprovação ou sugestão de financiamento
print("\n" + "=" * 60)
print("Conclusão:")
print("=" * 60)

if custo_total > 20000:
    if tipo_imovel == "residencial": # Removed emoji for consistency
        print("💰 Valor elevado para residência. Oferecemos:")
        print("  → Parcelamento em até 12x sem juros")
        print("  → Desconto de 5% para pagamento à vista")
    else:
        print("💰 Orçamento compatível com o porte do empreendimento")
        print("  → Condições especiais para empresas (consulte comercial).")
elif custo_total > 10000:
    print("💰 Orçamento médio. Prazo de execução confiável.")
    print("  → Parcelamento em até 6x sem juros.")
else:
    print("💰 Orçamento acessível. Ideal para execução imediata!")
    print("  → Pagamento à vista com 5% de desconto!")

# Verificação final de segurança
print("\n--- CHECKLIST DE SEGURANÇA ---")

if imovel_antigo == "s": # If it's an old property
    if fiacao_existente == "s": # If it also has recent reform
        print("⚠️ ATENÇÃO: Imóvel antigo com fiação existente reformada.")
        print("   → Necessário laudo de segurança da fiação e projeto de adequação de carga.")
        print("   → Contrate urgente uma vistoria técnica da Padron Elétrica.")
    else: # Old property without recent reform
        print("❌ CRÍTICO: Imóvel antigo sem reforma elétrica recente.")
        print("   → Necessário laudo de segurança da fiação e projeto de adequação de carga.")
        print("   → Contrate urgente uma vistoria técnica da Padron Elétrica.")
elif chuveiro_eletrico_quantidade > 0 and tipo_imovel == "residencial" and quantidade_comodos == 1:
    print("✓ Padrão: Chuveiro em kitnet - dimensionamento padrão")
else:
    print("✓ Instalação dentro dos padrões de segurança da Padron Elétrica.")

print("\n" + "=" * 60)
print("ORÇAMENTO VÁLIDO POR 30 DIAS")
print(f" ⚡ Padron Elétrica ⚡ - {nome_cliente}, aguardamos sua decisão!")
print("=" * 60)
# Out:
# ...
#   ⚡  SISTEMA DE ORÇAMENTO - Padron Elétrica ⚡
# ...
#
# --- DADOS DO CLIENTE ---
# Nome do cliente: BEN
# Tipo de imóvel (residencial/comercial/industrial): RESIDENCIAL
#
# ---📊 DADOS DA INSTALAÇÃO ---
# Área do imóvel (m²): 45
# Quantidade de cômodos: 6
# Possui projeto elétrico? (s/n): S
#
# --- 📝 NESSECIDADES ESPECÍFICAS  ---
# Vai instalar ar condicionado? ❄️ (s/n): S
# Quantos aparelhos de ar condicionado? ❄️ 3
# Vai usar chuveiro elétrico? 🚿 (s/n): S
# Quantos chuveiros elétricos? 🚿 2
# Deseja automação residencial? 📲 (s/n): S
#
# ...
#  📊[] CALCULANDO ORÇAMENTO E ANÁLISE TÉCNICA...
# ...
#
# ✓ Imóvel residencial: R$ 3375.00 (base)
# ✓ Instalação de 3 ar(es) condicionado(s): + R$ 1350.00
# ✓ Instalação de 2 chuveiro(s) elétrico(s): + R$ 700.00
#   ℹ️ Para imóveis com mais de 1 chuveiro elétrico, considere sistema de Potência.
# ✓ Automação residencial 📲: + R$ 1575.00
# ✓ Cliente possui projeto elétrico: 🗂️ - R$ 500.00 de desconto.
#
# ---  ⛑️ SEGURANÇA ---
# ...
