# %% [markdown]
# <a href="https://colab.research.google.com/github/razcarneiro/Aula-Logica-de-Programacao/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x=float(input("insira um número"))
y=float(input("insira um número"))

var1 = 2*x + 3/y
print(f"o resultado é{var1}")
