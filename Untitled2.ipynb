# %% [markdown]
# <a href="https://colab.research.google.com/github/razcarneiro/Aula-Logica-de-Programacao/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
palavra = input('escreva uma palavra:')
while palavra != "sair" and palavra != "Sair":
  print(palavra)
  palavra = input('escreva uma palavra:')
print("voce saiu do while ao digitar sair")

# %%
fator = 1
contador = 0
taxa = eval(input('digite a taxa de juros:'))
while contador <

# %%
s = 0
a = 1
while s < 5:
  s = 3*a
  a += 1
  print(s)
